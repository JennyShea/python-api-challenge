# %%
#imports pandas and shorten the name
import pandas as pd

#import numpy so you can use arrays and get random numbers and shorten the name
import numpy as np

#import matplotlib.pyplot so you can make plots and charts and shorten the name
import matplotlib.pyplot as pyplot

#import requests so you can make API calls
import requests

#import time so you can use dates and timepoints
import time


#import json so python can make sense of the data from the API call
import json

#import the ability to do linear regressions from the scipy.stats package
from scipy.stats import linregress

#import the API key for OpenWeather from the config file
from resource import api_key

#import the ability to find the nearest city to a set of coordinates 
#link is pip install citipy
from citipy import citipy

# %%
#create output file to use later
output_data_file = "output_data/cities.csv"

# %%
# make the range of latitudes that encompasses the whole world
lat_range = (-90,90)

#make the range of longitudes that emcompasses the whole world
long_range = (-180,180)

# %%
#create an empty list to hold the latitudes and longitudes
lat_longs = []

#create an empty list to hold the city names
cities =[]

# %%
#explain what's going to go in the lat_long list
#first, generate the random latitudes using numpy/np
#get random numbers for -90 to 90 deg latitude, getting 1,500 to be sure that there will be 500 to work with
#put them in a list and keep adding rows until you get 1,500 rows
lat = np.random.uniform(lat_range[0], lat_range[1], size=1500)

#do the same for longitudes
long = np.random.uniform(lat_range[0], lat_range[1], size = 1500)

#merge the files together into lat_long
lat_longs = zip(lat,long)

# %%
#find the cities nearest to the lat_long points 
#this is a for statement
# for each element in the lat_long list, 
for lat_long in lat_longs:
    #use the notation from citipy website
    #city = citipy.nearest_city(lat, long)
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name
    
    #if the name is unique, add it to the list of names
    if city not in cities:
        cities.append(city)
        
#Check how many cities there are
len(cities)
# Out:
# 596

# %%
#Temperature versus latitude for each city
#Write down what the format for API calls is
#Make that a variable, put the open weather specific part in quotes because it's a string
url= "http://api.openweathermap.org/data/2.5/weather?"

# %%
#Make a list to hold all the city data
city_data = []

#make a log so if/when something goes wrong you can find it
print("Beginning Data Retreival                   ")
print("-------------------------------------------")

#create a counter for the log, set the opening number of the counter at 1
record_count = 1
set_count = 1


#Loop through the cities and find a temperature for each city
#for each city in the city list, create an api call for the temperature if the city has a unique value with a maximum of 500. 
#use enumerate to loop through the cities to get a list of the cities and an index of number of iterations. This will need to be appended to. 

for i, city in enumerate (cities):
    
    #if the index number for a city in the city table has a remainder of 0 and the index of that city is greater than or equal to 50
    if (i % 50 == 0 and i >=50):
        #set the index of that city at 1 and run the group of numbers until you get to the next mod 0 as a set. Then take a 60 second break.
        set_count += 1
        record_count= 0
        #make a confirmation notice of set breaks
        print ("End of set.")
        time.sleep(60)
   #add a url for each city
    city_url = url + "q="+str({city})+"&appid="+{api_key}
    
    #print the record and set numbers in the log
    print (f" Record {record_count} of Set {set_count} | {city}")
    print (city_url)
    
    #start the record count at 1
    record_count +=1
      
    #run the API request for the cities and return it in a json formatted list
    try:

        city_weather = requests.get(city_url).json()
        
        #here are the items we want
        city_lat = city_weather["coord"]["lat"]
        city_long = city_weather["coord"]["lon"]
        city_temp = city_weather["main"]["temp_max"]
        city_humid = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        #add the the information into the city_data list and give it an easy to read column name
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Long": city_long,
                          "Max Temp": city_temp,
                          "Humidity": city_humid,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
        
       #if any of the retrivial requests is missing,print NA on the log 
    
    except:    
        print("NA")
        pass
    
    print("Process Complete")
# Out:
# Beginning Data Retreival
# -------------------------------------------
#  Record 1 of Set 1 | simi
# http://api.openweathermap.org/data/2.5/weather?q={'simi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q={'ponta do sol'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q={'hermanus'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 1 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?q={'nouadhibou'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?q={'chuy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 1 | kadnikov
# http://api.openweathermap.org/data/2.5/weather?q={'kadnikov'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 1 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?q={'sinnamary'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q={'cape town'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 1 | novo aripuana
# http://api.openweathermap.org/data/2.5/weather?q={'novo aripuana'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?q={'belushya guba'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 1 | forchheim
# http://api.openweathermap.org/data/2.5/weather?q={'forchheim'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 1 | hambantota
# http://api.openweathermap.org/data/2.5/weather?q={'hambantota'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 1 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?q={'keti bandar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q={'ushuaia'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 1 | colares
# http://api.openweathermap.org/data/2.5/weather?q={'colares'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 1 | henties bay
# http://api.openweathermap.org/data/2.5/weather?q={'henties bay'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q={'mar del plata'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q={'arraial do cabo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 1 | urdzhar
# http://api.openweathermap.org/data/2.5/weather?q={'urdzhar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?q={'souillac'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?q={'tsihombe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 1 | shalyhyne
# http://api.openweathermap.org/data/2.5/weather?q={'shalyhyne'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 1 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?q={'skjervoy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 1 | buraydah
# http://api.openweathermap.org/data/2.5/weather?q={'buraydah'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?q={'klaksvik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q={'taolanaro'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q={'saint-philippe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q={'jamestown'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 1 | yirol
# http://api.openweathermap.org/data/2.5/weather?q={'yirol'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?q={'padang'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 1 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q={'los llanos de aridane'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q={'hithadhoo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?q={'bathsheba'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 1 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?q={'marsh harbour'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 1 | biankouma
# http://api.openweathermap.org/data/2.5/weather?q={'biankouma'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 1 | brodowski
# http://api.openweathermap.org/data/2.5/weather?q={'brodowski'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?q={'east london'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?q={'nanortalik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 1 | moshenskoye
# http://api.openweathermap.org/data/2.5/weather?q={'moshenskoye'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 1 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?q={'meulaboh'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 1 | vardo
# http://api.openweathermap.org/data/2.5/weather?q={'vardo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 1 | falesti
# http://api.openweathermap.org/data/2.5/weather?q={'falesti'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?q={'amderma'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q={'carnarvon'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 1 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?q={'kalmunai'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 1 | upington
# http://api.openweathermap.org/data/2.5/weather?q={'upington'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q={'tasiilaq'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?q={'dikson'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 1 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?q={'saint anthony'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 50 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?q={'lebu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 2 | cajetina
# http://api.openweathermap.org/data/2.5/weather?q={'cajetina'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 2 | agadir
# http://api.openweathermap.org/data/2.5/weather?q={'agadir'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 2 | rawson
# http://api.openweathermap.org/data/2.5/weather?q={'rawson'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q={'port alfred'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?q={'ilulissat'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 2 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?q={'honningsvag'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 2 | bulungu
# http://api.openweathermap.org/data/2.5/weather?q={'bulungu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 2 | mungaoli
# http://api.openweathermap.org/data/2.5/weather?q={'mungaoli'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q={'port elizabeth'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 2 | aksu
# http://api.openweathermap.org/data/2.5/weather?q={'aksu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 2 | axim
# http://api.openweathermap.org/data/2.5/weather?q={'axim'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 2 | neyshabur
# http://api.openweathermap.org/data/2.5/weather?q={'neyshabur'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 2 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?q={'oksfjord'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 2 | tyazhinskiy
# http://api.openweathermap.org/data/2.5/weather?q={'tyazhinskiy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 2 | malanje
# http://api.openweathermap.org/data/2.5/weather?q={'malanje'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 2 | redcar
# http://api.openweathermap.org/data/2.5/weather?q={'redcar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 2 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?q={'ponta delgada'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 2 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?q={'san cristobal'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 2 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?q={'oranjestad'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 2 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?q={'rio gallegos'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?q={'barentsburg'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 2 | conde
# http://api.openweathermap.org/data/2.5/weather?q={'conde'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 2 | marawi
# http://api.openweathermap.org/data/2.5/weather?q={'marawi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q={'upernavik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 2 | bako
# http://api.openweathermap.org/data/2.5/weather?q={'bako'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q={'punta arenas'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 2 | santa fe
# http://api.openweathermap.org/data/2.5/weather?q={'santa fe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 2 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q={'coquimbo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?q={'saint george'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 2 | severodvinsk
# http://api.openweathermap.org/data/2.5/weather?q={'severodvinsk'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 2 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?q={'kavaratti'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 2 | ibra
# http://api.openweathermap.org/data/2.5/weather?q={'ibra'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 2 | salekhard
# http://api.openweathermap.org/data/2.5/weather?q={'salekhard'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 2 | mana
# http://api.openweathermap.org/data/2.5/weather?q={'mana'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 2 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?q={'batticaloa'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 2 | westport
# http://api.openweathermap.org/data/2.5/weather?q={'westport'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 2 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?q={'sept-iles'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q={'illoqqortoormiut'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 2 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?q={'taoudenni'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?q={'sao filipe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 2 | paamiut
# http://api.openweathermap.org/data/2.5/weather?q={'paamiut'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 2 | stephenville
# http://api.openweathermap.org/data/2.5/weather?q={'stephenville'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 2 | barroualie
# http://api.openweathermap.org/data/2.5/weather?q={'barroualie'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 2 | road town
# http://api.openweathermap.org/data/2.5/weather?q={'road town'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q={'attawapiskat'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?q={'georgetown'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 2 | muros
# http://api.openweathermap.org/data/2.5/weather?q={'muros'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?q={'busselton'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 2 | yarada
# http://api.openweathermap.org/data/2.5/weather?q={'yarada'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q={'kruisfontein'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 3 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?q={'ambilobe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 3 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?q={'umzimvubu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 3 | butajira
# http://api.openweathermap.org/data/2.5/weather?q={'butajira'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q={'bredasdorp'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 3 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?q={'saint-francois'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 3 | luderitz
# http://api.openweathermap.org/data/2.5/weather?q={'luderitz'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 3 | dzhusaly
# http://api.openweathermap.org/data/2.5/weather?q={'dzhusaly'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?q={'pisco'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 3 | husavik
# http://api.openweathermap.org/data/2.5/weather?q={'husavik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 3 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?q={'olafsvik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 3 | chipinge
# http://api.openweathermap.org/data/2.5/weather?q={'chipinge'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 3 | tsaratanana
# http://api.openweathermap.org/data/2.5/weather?q={'tsaratanana'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 3 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?q={'grand gaube'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 3 | novita
# http://api.openweathermap.org/data/2.5/weather?q={'novita'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 3 | soyo
# http://api.openweathermap.org/data/2.5/weather?q={'soyo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 3 | taltal
# http://api.openweathermap.org/data/2.5/weather?q={'taltal'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 3 | balsas
# http://api.openweathermap.org/data/2.5/weather?q={'balsas'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 3 | les cayes
# http://api.openweathermap.org/data/2.5/weather?q={'les cayes'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 3 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?q={'port-gentil'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?q={'iqaluit'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 3 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?q={'oranjemund'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 3 | shugurovo
# http://api.openweathermap.org/data/2.5/weather?q={'shugurovo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 3 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q={'comodoro rivadavia'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 3 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q={'cidreira'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q={'qaanaaq'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 3 | taloqan
# http://api.openweathermap.org/data/2.5/weather?q={'taloqan'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 3 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?q={'cockburn town'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 3 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?q={'muravlenko'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 3 | kromy
# http://api.openweathermap.org/data/2.5/weather?q={'kromy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 3 | usinsk
# http://api.openweathermap.org/data/2.5/weather?q={'usinsk'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 3 | ginir
# http://api.openweathermap.org/data/2.5/weather?q={'ginir'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 3 | mopipi
# http://api.openweathermap.org/data/2.5/weather?q={'mopipi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 3 | hamilton
# http://api.openweathermap.org/data/2.5/weather?q={'hamilton'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 3 | taguatinga
# http://api.openweathermap.org/data/2.5/weather?q={'taguatinga'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 3 | ob
# http://api.openweathermap.org/data/2.5/weather?q={'ob'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 3 | golspie
# http://api.openweathermap.org/data/2.5/weather?q={'golspie'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 3 | de aar
# http://api.openweathermap.org/data/2.5/weather?q={'de aar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 3 | pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?q={'pontes e lacerda'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 3 | leh
# http://api.openweathermap.org/data/2.5/weather?q={'leh'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 3 | canico
# http://api.openweathermap.org/data/2.5/weather?q={'canico'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 3 | nouakchott
# http://api.openweathermap.org/data/2.5/weather?q={'nouakchott'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 3 | kharp
# http://api.openweathermap.org/data/2.5/weather?q={'kharp'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 3 | goedereede
# http://api.openweathermap.org/data/2.5/weather?q={'goedereede'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 3 | matagami
# http://api.openweathermap.org/data/2.5/weather?q={'matagami'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 3 | khor
# http://api.openweathermap.org/data/2.5/weather?q={'khor'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 3 | tabas
# http://api.openweathermap.org/data/2.5/weather?q={'tabas'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 3 | hastings
# http://api.openweathermap.org/data/2.5/weather?q={'hastings'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 3 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?q={'aasiaat'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 3 | camabatela
# http://api.openweathermap.org/data/2.5/weather?q={'camabatela'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 3 | sasd
# http://api.openweathermap.org/data/2.5/weather?q={'sasd'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 4 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?q={'isla mujeres'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 4 | kibala
# http://api.openweathermap.org/data/2.5/weather?q={'kibala'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 4 | bilma
# http://api.openweathermap.org/data/2.5/weather?q={'bilma'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 4 | matane
# http://api.openweathermap.org/data/2.5/weather?q={'matane'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 4 | bonthe
# http://api.openweathermap.org/data/2.5/weather?q={'bonthe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 4 | dingle
# http://api.openweathermap.org/data/2.5/weather?q={'dingle'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 4 | harper
# http://api.openweathermap.org/data/2.5/weather?q={'harper'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 4 | grong
# http://api.openweathermap.org/data/2.5/weather?q={'grong'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 4 | yafran
# http://api.openweathermap.org/data/2.5/weather?q={'yafran'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 4 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q={'ribeira grande'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 4 | booue
# http://api.openweathermap.org/data/2.5/weather?q={'booue'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 4 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?q={'port shepstone'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 4 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q={'pangnirtung'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 4 | mehamn
# http://api.openweathermap.org/data/2.5/weather?q={'mehamn'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 4 | brae
# http://api.openweathermap.org/data/2.5/weather?q={'brae'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 4 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?q={'tumannyy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 4 | praia
# http://api.openweathermap.org/data/2.5/weather?q={'praia'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 4 | lalsk
# http://api.openweathermap.org/data/2.5/weather?q={'lalsk'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?q={'clyde river'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 4 | namanga
# http://api.openweathermap.org/data/2.5/weather?q={'namanga'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 4 | san pedro
# http://api.openweathermap.org/data/2.5/weather?q={'san pedro'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 4 | geraldton
# http://api.openweathermap.org/data/2.5/weather?q={'geraldton'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 4 | caravelas
# http://api.openweathermap.org/data/2.5/weather?q={'caravelas'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 4 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?q={'santa rosa'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 4 | ituni
# http://api.openweathermap.org/data/2.5/weather?q={'ituni'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 4 | tselinnoye
# http://api.openweathermap.org/data/2.5/weather?q={'tselinnoye'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 4 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?q={'vangaindrano'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 4 | krasnyy
# http://api.openweathermap.org/data/2.5/weather?q={'krasnyy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 4 | mubi
# http://api.openweathermap.org/data/2.5/weather?q={'mubi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 4 | macapa
# http://api.openweathermap.org/data/2.5/weather?q={'macapa'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 4 | talnakh
# http://api.openweathermap.org/data/2.5/weather?q={'talnakh'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 4 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q={'mahebourg'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 4 | calatayud
# http://api.openweathermap.org/data/2.5/weather?q={'calatayud'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 4 | neuquen
# http://api.openweathermap.org/data/2.5/weather?q={'neuquen'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 4 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?q={'grand river south east'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 4 | adrar
# http://api.openweathermap.org/data/2.5/weather?q={'adrar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 4 | salalah
# http://api.openweathermap.org/data/2.5/weather?q={'salalah'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 4 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?q={'maniitsoq'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 4 | benguela
# http://api.openweathermap.org/data/2.5/weather?q={'benguela'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 4 | marquette
# http://api.openweathermap.org/data/2.5/weather?q={'marquette'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 4 | trifesti
# http://api.openweathermap.org/data/2.5/weather?q={'trifesti'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 4 | villazon
# http://api.openweathermap.org/data/2.5/weather?q={'villazon'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 4 | kalomo
# http://api.openweathermap.org/data/2.5/weather?q={'kalomo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?q={'torbay'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?q={'touros'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 4 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?q={'tazovskiy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 4 | muzhi
# http://api.openweathermap.org/data/2.5/weather?q={'muzhi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 4 | emba
# http://api.openweathermap.org/data/2.5/weather?q={'emba'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 4 | lagdo
# http://api.openweathermap.org/data/2.5/weather?q={'lagdo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 4 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?q={'dhidhdhoo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 5 | gritsovskiy
# http://api.openweathermap.org/data/2.5/weather?q={'gritsovskiy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?q={'victoria'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 5 | huarmey
# http://api.openweathermap.org/data/2.5/weather?q={'huarmey'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 5 | maldonado
# http://api.openweathermap.org/data/2.5/weather?q={'maldonado'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 5 | atar
# http://api.openweathermap.org/data/2.5/weather?q={'atar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 5 | abyek
# http://api.openweathermap.org/data/2.5/weather?q={'abyek'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 5 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?q={'ilhabela'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 5 | maralal
# http://api.openweathermap.org/data/2.5/weather?q={'maralal'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 5 | codrington
# http://api.openweathermap.org/data/2.5/weather?q={'codrington'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 5 | tabou
# http://api.openweathermap.org/data/2.5/weather?q={'tabou'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 5 | kristiinankaupunki
# http://api.openweathermap.org/data/2.5/weather?q={'kristiinankaupunki'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 5 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q={'bambous virieux'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 5 | rudbar
# http://api.openweathermap.org/data/2.5/weather?q={'rudbar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 5 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?q={'puerto del rosario'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 5 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?q={'bolungarvik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 5 | peniche
# http://api.openweathermap.org/data/2.5/weather?q={'peniche'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 5 | necochea
# http://api.openweathermap.org/data/2.5/weather?q={'necochea'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 5 | sorvag
# http://api.openweathermap.org/data/2.5/weather?q={'sorvag'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 5 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?q={'yar-sale'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 5 | inhambupe
# http://api.openweathermap.org/data/2.5/weather?q={'inhambupe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 5 | vila velha
# http://api.openweathermap.org/data/2.5/weather?q={'vila velha'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 5 | yarkovo
# http://api.openweathermap.org/data/2.5/weather?q={'yarkovo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 5 | laguna
# http://api.openweathermap.org/data/2.5/weather?q={'laguna'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 5 | grindavik
# http://api.openweathermap.org/data/2.5/weather?q={'grindavik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 5 | hearst
# http://api.openweathermap.org/data/2.5/weather?q={'hearst'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 5 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?q={'la asuncion'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 5 | mgandu
# http://api.openweathermap.org/data/2.5/weather?q={'mgandu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 5 | sawakin
# http://api.openweathermap.org/data/2.5/weather?q={'sawakin'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 5 | lahr
# http://api.openweathermap.org/data/2.5/weather?q={'lahr'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 5 | kambove
# http://api.openweathermap.org/data/2.5/weather?q={'kambove'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 5 | lyubech
# http://api.openweathermap.org/data/2.5/weather?q={'lyubech'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 5 | takoradi
# http://api.openweathermap.org/data/2.5/weather?q={'takoradi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 5 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?q={'bengkulu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 5 | shurugwi
# http://api.openweathermap.org/data/2.5/weather?q={'shurugwi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 5 | bocaiuva
# http://api.openweathermap.org/data/2.5/weather?q={'bocaiuva'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 5 | matay
# http://api.openweathermap.org/data/2.5/weather?q={'matay'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 5 | tapaua
# http://api.openweathermap.org/data/2.5/weather?q={'tapaua'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 5 | oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?q={'oudtshoorn'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 5 | karaul
# http://api.openweathermap.org/data/2.5/weather?q={'karaul'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 5 | laukaa
# http://api.openweathermap.org/data/2.5/weather?q={'laukaa'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 5 | diamantino
# http://api.openweathermap.org/data/2.5/weather?q={'diamantino'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 5 | kidal
# http://api.openweathermap.org/data/2.5/weather?q={'kidal'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 5 | balykshi
# http://api.openweathermap.org/data/2.5/weather?q={'balykshi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 5 | korla
# http://api.openweathermap.org/data/2.5/weather?q={'korla'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 5 | imbituba
# http://api.openweathermap.org/data/2.5/weather?q={'imbituba'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 5 | herat
# http://api.openweathermap.org/data/2.5/weather?q={'herat'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 5 | muisne
# http://api.openweathermap.org/data/2.5/weather?q={'muisne'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 5 | tiznit
# http://api.openweathermap.org/data/2.5/weather?q={'tiznit'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 5 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q={'longyearbyen'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 5 | visnes
# http://api.openweathermap.org/data/2.5/weather?q={'visnes'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 6 | langevag
# http://api.openweathermap.org/data/2.5/weather?q={'langevag'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 6 | palmas
# http://api.openweathermap.org/data/2.5/weather?q={'palmas'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 6 | rocha
# http://api.openweathermap.org/data/2.5/weather?q={'rocha'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 6 | tahta
# http://api.openweathermap.org/data/2.5/weather?q={'tahta'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 6 | constitucion
# http://api.openweathermap.org/data/2.5/weather?q={'constitucion'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 6 | mayumba
# http://api.openweathermap.org/data/2.5/weather?q={'mayumba'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 6 | kortkeros
# http://api.openweathermap.org/data/2.5/weather?q={'kortkeros'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 6 | vallenar
# http://api.openweathermap.org/data/2.5/weather?q={'vallenar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 6 | marzuq
# http://api.openweathermap.org/data/2.5/weather?q={'marzuq'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 6 | bokspits
# http://api.openweathermap.org/data/2.5/weather?q={'bokspits'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 6 | zemio
# http://api.openweathermap.org/data/2.5/weather?q={'zemio'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 6 | kotma
# http://api.openweathermap.org/data/2.5/weather?q={'kotma'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 6 | balkhash
# http://api.openweathermap.org/data/2.5/weather?q={'balkhash'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 6 | sorland
# http://api.openweathermap.org/data/2.5/weather?q={'sorland'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 6 | wawa
# http://api.openweathermap.org/data/2.5/weather?q={'wawa'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 6 | dwarka
# http://api.openweathermap.org/data/2.5/weather?q={'dwarka'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 6 | hofn
# http://api.openweathermap.org/data/2.5/weather?q={'hofn'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 6 | gornyak
# http://api.openweathermap.org/data/2.5/weather?q={'gornyak'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 6 | wilmington
# http://api.openweathermap.org/data/2.5/weather?q={'wilmington'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 6 | port blair
# http://api.openweathermap.org/data/2.5/weather?q={'port blair'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 6 | pocone
# http://api.openweathermap.org/data/2.5/weather?q={'pocone'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 6 | richards bay
# http://api.openweathermap.org/data/2.5/weather?q={'richards bay'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 6 | rivadavia
# http://api.openweathermap.org/data/2.5/weather?q={'rivadavia'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 6 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?q={'thinadhoo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 6 | semme
# http://api.openweathermap.org/data/2.5/weather?q={'semme'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 6 | marcona
# http://api.openweathermap.org/data/2.5/weather?q={'marcona'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 6 | elsterwerda
# http://api.openweathermap.org/data/2.5/weather?q={'elsterwerda'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 6 | cachira
# http://api.openweathermap.org/data/2.5/weather?q={'cachira'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 6 | springbok
# http://api.openweathermap.org/data/2.5/weather?q={'springbok'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 6 | antalaha
# http://api.openweathermap.org/data/2.5/weather?q={'antalaha'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 6 | lodwar
# http://api.openweathermap.org/data/2.5/weather?q={'lodwar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 6 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?q={'strezhevoy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 6 | katsiveli
# http://api.openweathermap.org/data/2.5/weather?q={'katsiveli'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 6 | eyl
# http://api.openweathermap.org/data/2.5/weather?q={'eyl'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 6 | berberati
# http://api.openweathermap.org/data/2.5/weather?q={'berberati'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 6 | crab hill
# http://api.openweathermap.org/data/2.5/weather?q={'crab hill'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 6 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?q={'saint-augustin'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 6 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q={'saint-pierre'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 6 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?q={'virginia beach'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 6 | coihueco
# http://api.openweathermap.org/data/2.5/weather?q={'coihueco'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 6 | lunel
# http://api.openweathermap.org/data/2.5/weather?q={'lunel'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 6 | kuche
# http://api.openweathermap.org/data/2.5/weather?q={'kuche'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 6 | veinticinco de mayo
# http://api.openweathermap.org/data/2.5/weather?q={'veinticinco de mayo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q={'saldanha'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 6 | ipixuna
# http://api.openweathermap.org/data/2.5/weather?q={'ipixuna'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 6 | filadelfia
# http://api.openweathermap.org/data/2.5/weather?q={'filadelfia'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 6 | shchuchye
# http://api.openweathermap.org/data/2.5/weather?q={'shchuchye'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 6 | buncrana
# http://api.openweathermap.org/data/2.5/weather?q={'buncrana'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 6 | bonavista
# http://api.openweathermap.org/data/2.5/weather?q={'bonavista'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 6 | ghanzi
# http://api.openweathermap.org/data/2.5/weather?q={'ghanzi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 7 | camacha
# http://api.openweathermap.org/data/2.5/weather?q={'camacha'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 7 | sechura
# http://api.openweathermap.org/data/2.5/weather?q={'sechura'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 7 | najran
# http://api.openweathermap.org/data/2.5/weather?q={'najran'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 7 | scottsburgh
# http://api.openweathermap.org/data/2.5/weather?q={'scottsburgh'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 7 | puerto concordia
# http://api.openweathermap.org/data/2.5/weather?q={'puerto concordia'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 7 | cayenne
# http://api.openweathermap.org/data/2.5/weather?q={'cayenne'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 7 | kysucke nove mesto
# http://api.openweathermap.org/data/2.5/weather?q={'kysucke nove mesto'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 7 | dax
# http://api.openweathermap.org/data/2.5/weather?q={'dax'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 7 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?q={'bandarbeyla'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 7 | suez
# http://api.openweathermap.org/data/2.5/weather?q={'suez'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 7 | den helder
# http://api.openweathermap.org/data/2.5/weather?q={'den helder'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 7 | igarka
# http://api.openweathermap.org/data/2.5/weather?q={'igarka'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 7 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?q={'alta floresta'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 7 | stodolishche
# ...
# http://api.openweathermap.org/data/2.5/weather?q={'havre-saint-pierre'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 10 | chapais
# http://api.openweathermap.org/data/2.5/weather?q={'chapais'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 10 | atbasar
# http://api.openweathermap.org/data/2.5/weather?q={'atbasar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 10 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?q={'antofagasta'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 10 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?q={'salinopolis'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 10 | minab
# http://api.openweathermap.org/data/2.5/weather?q={'minab'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 10 | pangody
# http://api.openweathermap.org/data/2.5/weather?q={'pangody'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 10 | ormara
# http://api.openweathermap.org/data/2.5/weather?q={'ormara'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 11 | elesbao veloso
# http://api.openweathermap.org/data/2.5/weather?q={'elesbao veloso'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 11 | choya
# http://api.openweathermap.org/data/2.5/weather?q={'choya'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 11 | reconquista
# http://api.openweathermap.org/data/2.5/weather?q={'reconquista'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 11 | rafai
# http://api.openweathermap.org/data/2.5/weather?q={'rafai'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 11 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?q={'elizabeth city'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 11 | gurlan
# http://api.openweathermap.org/data/2.5/weather?q={'gurlan'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 11 | gol
# http://api.openweathermap.org/data/2.5/weather?q={'gol'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 11 | porto empedocle
# http://api.openweathermap.org/data/2.5/weather?q={'porto empedocle'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 11 | rodrigues alves
# http://api.openweathermap.org/data/2.5/weather?q={'rodrigues alves'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 11 | manicore
# http://api.openweathermap.org/data/2.5/weather?q={'manicore'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 11 | ilebo
# http://api.openweathermap.org/data/2.5/weather?q={'ilebo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 11 | dhanaula
# http://api.openweathermap.org/data/2.5/weather?q={'dhanaula'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 11 | mollendo
# http://api.openweathermap.org/data/2.5/weather?q={'mollendo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 11 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?q={'umm lajj'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 11 | mahadday weyne
# http://api.openweathermap.org/data/2.5/weather?q={'mahadday weyne'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 11 | oistins
# http://api.openweathermap.org/data/2.5/weather?q={'oistins'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 11 | talawdi
# http://api.openweathermap.org/data/2.5/weather?q={'talawdi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 11 | araouane
# http://api.openweathermap.org/data/2.5/weather?q={'araouane'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 11 | carutapera
# http://api.openweathermap.org/data/2.5/weather?q={'carutapera'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 11 | eganville
# http://api.openweathermap.org/data/2.5/weather?q={'eganville'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 11 | talmenka
# http://api.openweathermap.org/data/2.5/weather?q={'talmenka'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 11 | kananga
# http://api.openweathermap.org/data/2.5/weather?q={'kananga'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 11 | arroyo
# http://api.openweathermap.org/data/2.5/weather?q={'arroyo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 11 | watsa
# http://api.openweathermap.org/data/2.5/weather?q={'watsa'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 11 | camopi
# http://api.openweathermap.org/data/2.5/weather?q={'camopi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 11 | niono
# http://api.openweathermap.org/data/2.5/weather?q={'niono'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 11 | idar
# http://api.openweathermap.org/data/2.5/weather?q={'idar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 11 | atakpame
# http://api.openweathermap.org/data/2.5/weather?q={'atakpame'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 11 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?q={'saint-joseph'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 11 | nantucket
# http://api.openweathermap.org/data/2.5/weather?q={'nantucket'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 11 | trairi
# http://api.openweathermap.org/data/2.5/weather?q={'trairi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 11 | macon
# http://api.openweathermap.org/data/2.5/weather?q={'macon'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 11 | amarkantak
# http://api.openweathermap.org/data/2.5/weather?q={'amarkantak'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 11 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?q={'mogadishu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 11 | bhagalpur
# http://api.openweathermap.org/data/2.5/weather?q={'bhagalpur'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 11 | kuusamo
# http://api.openweathermap.org/data/2.5/weather?q={'kuusamo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 11 | san pedro de macoris
# http://api.openweathermap.org/data/2.5/weather?q={'san pedro de macoris'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 11 | itarema
# http://api.openweathermap.org/data/2.5/weather?q={'itarema'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 11 | chambas
# http://api.openweathermap.org/data/2.5/weather?q={'chambas'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 11 | deep river
# http://api.openweathermap.org/data/2.5/weather?q={'deep river'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 11 | pachperwa
# http://api.openweathermap.org/data/2.5/weather?q={'pachperwa'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 11 | moose factory
# http://api.openweathermap.org/data/2.5/weather?q={'moose factory'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 11 | san felipe
# http://api.openweathermap.org/data/2.5/weather?q={'san felipe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 11 | paita
# http://api.openweathermap.org/data/2.5/weather?q={'paita'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 11 | zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?q={'zhanakorgan'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 11 | sozimskiy
# http://api.openweathermap.org/data/2.5/weather?q={'sozimskiy'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 46 of Set 11 | george
# http://api.openweathermap.org/data/2.5/weather?q={'george'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 47 of Set 11 | coihaique
# http://api.openweathermap.org/data/2.5/weather?q={'coihaique'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 48 of Set 11 | bandar-e lengeh
# http://api.openweathermap.org/data/2.5/weather?q={'bandar-e lengeh'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 49 of Set 11 | libourne
# http://api.openweathermap.org/data/2.5/weather?q={'libourne'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
# End of set.
#  Record 0 of Set 12 | pasan
# http://api.openweathermap.org/data/2.5/weather?q={'pasan'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 1 of Set 12 | bhachau
# http://api.openweathermap.org/data/2.5/weather?q={'bhachau'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 2 of Set 12 | miandrivazo
# http://api.openweathermap.org/data/2.5/weather?q={'miandrivazo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 3 of Set 12 | mumford
# http://api.openweathermap.org/data/2.5/weather?q={'mumford'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 4 of Set 12 | mrirt
# http://api.openweathermap.org/data/2.5/weather?q={'mrirt'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 5 of Set 12 | roanoke rapids
# http://api.openweathermap.org/data/2.5/weather?q={'roanoke rapids'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 6 of Set 12 | staroye drozhzhanoye
# http://api.openweathermap.org/data/2.5/weather?q={'staroye drozhzhanoye'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 7 of Set 12 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?q={'pitimbu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 8 of Set 12 | garmsar
# http://api.openweathermap.org/data/2.5/weather?q={'garmsar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 9 of Set 12 | corinto
# http://api.openweathermap.org/data/2.5/weather?q={'corinto'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 10 of Set 12 | dalvik
# http://api.openweathermap.org/data/2.5/weather?q={'dalvik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 11 of Set 12 | bhanpura
# http://api.openweathermap.org/data/2.5/weather?q={'bhanpura'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 12 of Set 12 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?q={'boca do acre'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 13 of Set 12 | ravar
# http://api.openweathermap.org/data/2.5/weather?q={'ravar'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 14 of Set 12 | beckley
# http://api.openweathermap.org/data/2.5/weather?q={'beckley'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 15 of Set 12 | rabat
# http://api.openweathermap.org/data/2.5/weather?q={'rabat'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 16 of Set 12 | gamba
# http://api.openweathermap.org/data/2.5/weather?q={'gamba'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 17 of Set 12 | borama
# http://api.openweathermap.org/data/2.5/weather?q={'borama'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 18 of Set 12 | lamu
# http://api.openweathermap.org/data/2.5/weather?q={'lamu'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 19 of Set 12 | casablanca
# http://api.openweathermap.org/data/2.5/weather?q={'casablanca'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 20 of Set 12 | miraflores
# http://api.openweathermap.org/data/2.5/weather?q={'miraflores'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 21 of Set 12 | veraval
# http://api.openweathermap.org/data/2.5/weather?q={'veraval'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 22 of Set 12 | sainte-maxime
# http://api.openweathermap.org/data/2.5/weather?q={'sainte-maxime'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 23 of Set 12 | namibe
# http://api.openweathermap.org/data/2.5/weather?q={'namibe'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 24 of Set 12 | carlisle
# http://api.openweathermap.org/data/2.5/weather?q={'carlisle'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 25 of Set 12 | jabinyanah
# http://api.openweathermap.org/data/2.5/weather?q={'jabinyanah'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 26 of Set 12 | panaba
# http://api.openweathermap.org/data/2.5/weather?q={'panaba'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 27 of Set 12 | point pleasant
# http://api.openweathermap.org/data/2.5/weather?q={'point pleasant'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 28 of Set 12 | karasjok
# http://api.openweathermap.org/data/2.5/weather?q={'karasjok'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 29 of Set 12 | bani
# http://api.openweathermap.org/data/2.5/weather?q={'bani'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 30 of Set 12 | ocala
# http://api.openweathermap.org/data/2.5/weather?q={'ocala'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 31 of Set 12 | greenfield
# http://api.openweathermap.org/data/2.5/weather?q={'greenfield'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 32 of Set 12 | samur
# http://api.openweathermap.org/data/2.5/weather?q={'samur'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 33 of Set 12 | vazante
# http://api.openweathermap.org/data/2.5/weather?q={'vazante'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 34 of Set 12 | saint-esteve
# http://api.openweathermap.org/data/2.5/weather?q={'saint-esteve'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 35 of Set 12 | sylacauga
# http://api.openweathermap.org/data/2.5/weather?q={'sylacauga'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 36 of Set 12 | bud
# http://api.openweathermap.org/data/2.5/weather?q={'bud'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 37 of Set 12 | sokolo
# http://api.openweathermap.org/data/2.5/weather?q={'sokolo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 38 of Set 12 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?q={'kudahuvadhoo'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 39 of Set 12 | los andes
# http://api.openweathermap.org/data/2.5/weather?q={'los andes'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 40 of Set 12 | marfino
# http://api.openweathermap.org/data/2.5/weather?q={'marfino'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 41 of Set 12 | gobabis
# http://api.openweathermap.org/data/2.5/weather?q={'gobabis'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 42 of Set 12 | pascagoula
# http://api.openweathermap.org/data/2.5/weather?q={'pascagoula'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 43 of Set 12 | urumqi
# http://api.openweathermap.org/data/2.5/weather?q={'urumqi'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 44 of Set 12 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?q={'ornskoldsvik'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete
#  Record 45 of Set 12 | luau
# http://api.openweathermap.org/data/2.5/weather?q={'luau'}&appid=7109fdb7138035e7274a91ec2c86432a
# NA
# Process Complete

# %%
 #add a url for each city
